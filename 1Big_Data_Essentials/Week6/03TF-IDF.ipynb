# %%
# %%writefile mapper.py

from __future__ import division
import sys
import re
from collections import Counter

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

with open('stop_words_en.txt') as f:
    stop_words = set(f.read().split())

for line in sys.stdin:
    
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
        article_id = int(article_id)
    except ValueError as e:
        continue
        
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    words = [x.lower() for x in words if x.lower() not in stop_words]
    words_count = Counter(words)
    N = len(words)
    
    for word, count in words_count.items():
        tf = count / N
        print "%s\t%d\t%f" % (word, article_id, tf)
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py

from __future__ import division
import sys
from math import log

cur_word = None

for line in sys.stdin:
    
    try:
        word, article_id, tf = line.strip().split('\t')
        article_id, tf = int(article_id), float(tf)
    except ValueError as e:
        continue
        
    if cur_word != word:
        if cur_word:
            idf = 1 / log(1 + Dt)
            
            for a_id, a_tf in article_tf:
                tfidf = a_tf * idf
                print "%s\t%d\t%f" % (cur_word, a_id, tfidf)
        
        Dt = 0
        article_tf = []
        cur_word = word
    
    Dt += 1
    article_tf.append((article_id, tf))
    
if cur_word:
    idf = 1 / log(1 + Dt)
    
    for a_id, a_tf in article_tf:
        tfidf = a_tf * idf
        print "%s\t%d\t%f" % (cur_word, a_id, tfidf)
# Out:
# Overwriting reducer.py

# %%
# %%bash
#
# OUT_DIR="TFIDF_"$(date +"%s%6N")
# NUM_REDUCERS=8
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming TF-IDF" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper.py,reducer.py,/datasets/stop_words_en.txt \
#     -mapper "python mapper.py" \
#     -reducer "python reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
# hdfs dfs -cat tf_idf/* | grep -P 'labor\t12\t' | cut -f3
# Out:
# rm: `TFIDF_1536901873079553': No such file or directory
# 18/09/14 05:11:16 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/09/14 05:11:16 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/09/14 05:11:17 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/09/14 05:11:18 INFO mapreduce.JobSubmitter: number of splits:2
# 18/09/14 05:11:18 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1536901027046_0004
# 18/09/14 05:11:18 INFO impl.YarnClientImpl: Submitted application application_1536901027046_0004
# 18/09/14 05:11:18 INFO mapreduce.Job: The url to track the job: http://6564fbf716aa:8088/proxy/application_1536901027046_0004/
# 18/09/14 05:11:18 INFO mapreduce.Job: Running job: job_1536901027046_0004
# 18/09/14 05:11:24 INFO mapreduce.Job: Job job_1536901027046_0004 running in uber mode : false
# 18/09/14 05:11:24 INFO mapreduce.Job:  map 0% reduce 0%
# 18/09/14 05:11:40 INFO mapreduce.Job:  map 65% reduce 0%
# 18/09/14 05:11:43 INFO mapreduce.Job:  map 82% reduce 0%
# 18/09/14 05:11:44 INFO mapreduce.Job:  map 100% reduce 0%
# 18/09/14 05:11:51 INFO mapreduce.Job:  map 100% reduce 25%
# 18/09/14 05:11:54 INFO mapreduce.Job:  map 100% reduce 38%
# 18/09/14 05:11:55 INFO mapreduce.Job:  map 100% reduce 50%
# 18/09/14 05:11:56 INFO mapreduce.Job:  map 100% reduce 75%
# 18/09/14 05:11:57 INFO mapreduce.Job:  map 100% reduce 88%
# 18/09/14 05:11:58 INFO mapreduce.Job:  map 100% reduce 100%
# 18/09/14 05:11:58 INFO mapreduce.Job: Job job_1536901027046_0004 completed successfully
# 18/09/14 05:11:58 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=83708136
# 		FILE: Number of bytes written=168815786
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=76761713
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=34141
# 		Total time spent by all reduces in occupied slots (ms)=42373
# 		Total time spent by all map tasks (ms)=34141
# 		Total time spent by all reduce tasks (ms)=42373
# 		Total vcore-milliseconds taken by all map tasks=34141
# 		Total vcore-milliseconds taken by all reduce tasks=42373
# 		Total megabyte-milliseconds taken by all map tasks=34960384
# 		Total megabyte-milliseconds taken by all reduce tasks=43389952
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=3472743
# 		Map output bytes=76762592
# 		Map output materialized bytes=83708184
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=426865
# 		Reduce shuffle bytes=83708184
# 		Reduce input records=3472743
# 		Reduce output records=3472685
# 		Spilled Records=6945486
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=958
# 		CPU time spent (ms)=52780
# 		Physical memory (bytes) snapshot=2205040640
# 		Virtual memory (bytes) snapshot=20176379904
# 		Total committed heap usage (bytes)=1558708224
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=76761713
# 18/09/14 05:11:58 INFO streaming.StreamJob: Output directory: TFIDF_1536901873079553
# cat: `tf_idf/*': No such file or directory
